# %%
import pandas as pd

# %%
df = pd.read_csv("temperatures.csv")

# %%
df
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
df.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
df.tail()
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 112  30.27  27.83  25.37   29.81    25.58    32.58    31.33    27.83
# 113  30.29  28.05  25.08   29.72    24.90    31.82    32.00    27.81
# 114  31.04  28.10  25.67   29.90    25.74    31.68    31.87    28.27
# 115  31.98  30.11  28.01   31.63    28.33    34.57    32.28    30.03
# 116  32.29  29.60  27.18   31.42    27.95    34.13    32.41    29.69

# %%
df.columns
# Out:
# Index(['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP',
#        'OCT', 'NOV', 'DEC', 'ANNUAL', 'JAN-FEB', 'MAR-MAY', 'JUN-SEP',
#        'OCT-DEC'],
#       dtype='object')

# %%
len(df)
# Out:
# 117

# %%
df.dtypes
# Out:
# YEAR         int64
# JAN        float64
# FEB        float64
# MAR        float64
# APR        float64
# MAY        float64
# JUN        float64
# JUL        float64
# AUG        float64
# SEP        float64
# OCT        float64
# NOV        float64
# DEC        float64
# ANNUAL     float64
# JAN-FEB    float64
# MAR-MAY    float64
# JUN-SEP    float64
# OCT-DEC    float64
# dtype: object

# %%
df.dtypes

# %%
df.head(10)

# %%
df.shape
# Out:
# (117, 18)

# %%
x = df.shape
type(x)
# Out:
# tuple

# %%
df.iloc[0:5,:]
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
df.iloc[5:,5:]
# Out:
#        MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  JAN-FEB  \
# 5    34.11  32.19  31.01  30.30  29.92  29.55  27.60  24.72   28.73    23.03
# 6    32.68  31.92  31.05  29.58  30.67  29.87  27.78  24.44   28.65    24.23
# 7    33.02  33.12  30.61  29.55  29.59  29.35  26.88  23.73   28.83    24.42
# 8    33.06  31.70  29.81  29.81  30.06  29.25  27.69  23.69   28.38    23.52
# 9    33.51  31.84  30.42  29.86  29.82  28.91  26.32  23.37   28.53    24.20
# ..     ...    ...    ...    ...    ...    ...    ...    ...     ...      ...
# 112  34.46  32.44  31.07  30.76  31.04  30.27  27.83  25.37   29.81    25.58
# 113  33.77  34.15  31.85  31.32  30.68  30.29  28.05  25.08   29.72    24.90
# 114  34.09  32.48  31.88  31.52  31.55  31.04  28.10  25.67   29.90    25.74
# 115  35.72  34.03  31.64  31.79  31.66  31.98  30.11  28.01   31.63    28.33
# 116  35.84  33.82  31.88  31.72  32.22  32.29  29.60  27.18   31.42    27.95
#
#      MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
df.iloc[6:,10:]
# Out:
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 6    29.87  27.78  24.44   28.65    24.23    29.92    30.80    27.36
# 7    29.35  26.88  23.73   28.83    24.42    31.43    30.72    26.64
# 8    29.25  27.69  23.69   28.38    23.52    31.02    30.33    26.88
# 9    28.91  26.32  23.37   28.53    24.20    31.14    30.48    26.20
# 10   29.43  25.70  23.71   28.62    23.90    30.70    31.14    26.31
# ..     ...    ...    ...     ...      ...      ...      ...      ...
# 112  30.27  27.83  25.37   29.81    25.58    32.58    31.33    27.83
# 113  30.29  28.05  25.08   29.72    24.90    31.82    32.00    27.81
# 114  31.04  28.10  25.67   29.90    25.74    31.68    31.87    28.27
# 115  31.98  30.11  28.01   31.63    28.33    34.57    32.28    30.03
# 116  32.29  29.60  27.18   31.42    27.95    34.13    32.41    29.69
#
# [111 rows x 8 columns]

# %%
df.iloc[9,:]
# Out:
# YEAR       1910.00
# JAN          23.24
# FEB          25.16
# MAR          28.48
# APR          31.42
# MAY          33.51
# JUN          31.84
# JUL          30.42
# AUG          29.86
# SEP          29.82
# OCT          28.91
# NOV          26.32
# DEC          23.37
# ANNUAL       28.53
# JAN-FEB      24.20
# MAR-MAY      31.14
# JUN-SEP      30.48
# OCT-DEC      26.20
# Name: 9, dtype: float64

# %%
df.loc[9,:]
# Out:
# YEAR       1910.00
# JAN          23.24
# FEB          25.16
# MAR          28.48
# APR          31.42
# MAY          33.51
# JUN          31.84
# JUL          30.42
# AUG          29.86
# SEP          29.82
# OCT          28.91
# NOV          26.32
# DEC          23.37
# ANNUAL       28.53
# JAN-FEB      24.20
# MAR-MAY      31.14
# JUN-SEP      30.48
# OCT-DEC      26.20
# Name: 9, dtype: float64

# %%
df.loc[:5,:]
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
# 5  1906  22.28  23.69  27.31  31.93  34.11  32.19  31.01  30.30  29.92  29.55
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57
# 5  27.60  24.72   28.73    23.03    31.11    30.86    27.29

# %%
df.loc[:5,"YEAR"]
# Out:
# 0    1901
# 1    1902
# 2    1903
# 3    1904
# 4    1905
# 5    1906
# Name: YEAR, dtype: int64

# %%
df.loc[:10,["YEAR","JAN"]]
# Out:
#     YEAR    JAN
# 0   1901  22.40
# 1   1902  24.93
# 2   1903  23.44
# 3   1904  22.50
# 4   1905  22.00
# 5   1906  22.28
# 6   1907  24.46
# 7   1908  23.57
# 8   1909  22.67
# 9   1910  23.24
# 10  1911  23.22
